# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/demos/stats.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'staircase_pet_score', 'scout_score',
#        'sokoban_reached_score', 'charisma', 'experience_points', 'step',
#        'hitpoints', 'sokoban_fill_pit_score', 'experience_level',
#        'staircase_score', 'max_energy', 'constitution',
#        'sokoban_solved_levels_score', 'energy', 'score', 'armor_class',
#        'max_dlvl', 'strength', 'eating_score', 'intelligence', 'dexterity',
#        'wisdom', 'dlvl', 'max_hitpoints', 'sokoban_solved_score', 'ttyrecname',
#        'gold'],
#       dtype='object')

# %%
df[df["sokoban_reached_score"] > 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, staircase_pet_score, scout_score, sokoban_reached_score, charisma, experience_points, step, hitpoints, sokoban_fill_pit_score, experience_level, staircase_score, max_energy, constitution, sokoban_solved_levels_score, energy, score, armor_class, max_dlvl, strength, eating_score, intelligence, dexterity, wisdom, dlvl, max_hitpoints, sokoban_solved_score, ttyrecname, gold]
# Index: []
#
# [0 rows x 28 columns]

# %%
for key in ["experience_level", "max_dlvl", "armor_class"]:
    plt.hist(df[key], label=key)
    plt.legend()
    plt.show()
